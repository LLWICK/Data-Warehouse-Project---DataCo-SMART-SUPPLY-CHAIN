# %%
import pandas as pd

# %%
# Load dataset
df = pd.read_csv("../raw_dataset/DataCoSupplyChainDataset.csv", encoding="latin1")
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %%
df.shape
# Out:
# (180519, 53)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %% [markdown]
# # Customer Data

# %%
# ---------------------------
# 1. CUSTOMER CSV
# ---------------------------
customers_df = df[[
    "Customer Id",
    "Customer Fname",
    "Customer Lname",
    "Customer City",
    "Customer Country",
    "Customer State",
    "Customer Street",
    "Customer Zipcode",
    "Customer Segment",
    
]].drop_duplicates()

# %%
customers_df.shape
# Out:
# (20652, 9)

# %%
customers_df.head()
# Out:
#    Customer Id Customer Fname Customer Lname Customer City Customer Country  \
# 0        20755          Cally       Holloway        Caguas      Puerto Rico
# 1        19492          Irene           Luna        Caguas      Puerto Rico
# 2        19491        Gillian      Maldonado      San Jose          EE. UU.
# 3        19490           Tana           Tate   Los Angeles          EE. UU.
# 4        19489           Orli      Hendricks        Caguas      Puerto Rico
#
#   Customer State           Customer Street  Customer Zipcode Customer Segment
# 0             PR  5365 Noble Nectar Island             725.0         Consumer
# 1             PR          2679 Rustic Loop             725.0         Consumer
# 2             CA      8510 Round Bear Gate           95125.0         Consumer
# 3             CA           3200 Amber Bend           90027.0      Home Office
# 4             PR  8671 Iron Anchor Corners             725.0        Corporate

# %%
customers_df.to_csv("./data/customers.csv", index=False)

# %% [markdown]
# # Orders

# %%
orders_df = df[[
    'Order Id', 'Customer Id', 'order date (DateOrders)', 'Order Status','Order Region','Order State'
]].drop_duplicates()

# %%
orders_df.head()
# Out:
#    Order Id  Customer Id order date (DateOrders)     Order Status  \
# 0     77202        20755         1/31/2018 22:56         COMPLETE
# 1     75939        19492         1/13/2018 12:27          PENDING
# 2     75938        19491         1/13/2018 12:06           CLOSED
# 3     75937        19490         1/13/2018 11:45         COMPLETE
# 4     75936        19489         1/13/2018 11:24  PENDING_PAYMENT
#
#      Order Region      Order State
# 0  Southeast Asia  Java Occidental
# 1      South Asia         Rajastán
# 2      South Asia         Rajastán
# 3         Oceania       Queensland
# 4         Oceania       Queensland

# %%
orders_df.shape
# Out:
# (65752, 6)

# %%
orders_df.to_csv("./data/orders.csv", index=False)

# %% [markdown]
# # Order Items

# %%
order_items = df[[
    'Order Item Id','Order Id','Product Category Id', 'Order Item Quantity', 'Order Item Product Price', 
    'Order Item Total'
]].drop_duplicates()

# %%
order_items.shape
# Out:
# (180519, 6)

# %%
order_items.head()
# Out:
#    Order Item Id  Order Id  Product Category Id  Order Item Quantity  \
# 0         180517     77202                   73                    1
# 1         179254     75939                   73                    1
# 2         179253     75938                   73                    1
# 3         179252     75937                   73                    1
# 4         179251     75936                   73                    1
#
#    Order Item Product Price  Order Item Total
# 0                    327.75        314.640015
# 1                    327.75        311.359985
# 2                    327.75        309.720001
# 3                    327.75        304.809998
# 4                    327.75        298.250000

# %%
order_items.to_csv("./data/order_items.csv", index=False)

# %% [markdown]
# # Products

# %%
products_df = df[[
    'Product Card Id', 'Product Category Id',
    'Product Name', 'Product Price'
]].drop_duplicates()

# %%
products_df.shape
# Out:
# (118, 4)

# %%
products_df.head()
# Out:
#     Product Card Id  Product Category Id  \
# 0              1360                   73
# 48              365                   17
# 49              627                   29
# 50              502                   24
# 55              278                   13
#
#                                      Product Name  Product Price
# 0                                    Smart watch      327.750000
# 48               Perfect Fitness Perfect Rip Deck      59.990002
# 49  Under Armour Girls' Toddler Spine Surge Runni      39.990002
# 50           Nike Men's Dri-FIT Victory Golf Polo      50.000000
# 55     Under Armour Men's Compression EV SL Slide      44.990002

# %%
products_df.to_excel("./data/products.xlsx", index=False)

# %% [markdown]
# # Category

# %%
category_df = df[[
    'Category Id',
    'Category Name'
]].drop_duplicates()

# %%
category_df.head(20)
# Out:
#      Category Id         Category Name
# 0             73        Sporting Goods
# 48            17                Cleats
# 49            29         Shop By Sport
# 50            24       Women's Apparel
# 55            13           Electronics
# 56            12          Boxing & MMA
# 59             9      Cardio Equipment
# 61            41              Trade-In
# 62            37           Electronics
# 117           38      Kids' Golf Clubs
# 118           44    Hunting & Shooting
# 119            3   Baseball & Softball
# 138           18        Men's Footwear
# 143           43      Camping & Hiking
# 145           65  Consumer Electronics
# 146           62              Cameras
# 152           64             Computers
# 174            4            Basketball
# 175            2                Soccer
# 191           26        Girls' Apparel

# %%
category_df.to_excel("./data/category.xlsx", index=False)

# %% [markdown]
# # Shipping

# %%
shipping_df = df[[
    'Order Id', 'shipping date (DateOrders)',
    'Shipping Mode', 'Delivery Status'
]].drop_duplicates()

# %%
shipping_df.shape
# Out:
# (65752, 4)

# %%
shipping_df.shape
# Out:
# (65752, 4)

# %%
shipping_df.to_csv("./data/shipping.csv", index=False)
